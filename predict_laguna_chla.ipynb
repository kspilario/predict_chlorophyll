# %% [markdown]
# # Data-driven Modelling of Chlorophyll-a from Nitrogen and Phosphorus Content

# %%
import optuna
from optuna.samplers import TPESampler
from optuna.visualization.matplotlib import plot_optimization_history
from optuna.visualization._optimization_history import _get_optimization_history_info_list

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, DotProduct, Matern
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.cluster import KMeans
from sklearn.svm import SVR
from time import time
import numpy as np
import pandas as pd
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
start = time()
df = pd.read_csv("chlor.csv")
df.head()
# Out:
#    Chl_a   Phy      NO2       NO3        NH4        PO4 Site       Bay  Depth
# 0   6.66  0.74  0.21830  0.522735  31.784807  15.317651  XVI  West Bay  1.097
# 1   6.45  0.78  0.21830  0.522735  31.784807  15.317651  XVI  West Bay  1.098
# 2   6.27  0.77  0.21830  0.522735  31.784807  15.317651  XVI  West Bay  1.098
# 3   6.13  0.58  0.21495  0.527931  30.446107  14.834307  XVI  West Bay  2.004
# 4   6.10  0.57  0.21495  0.527931  30.446107  14.834307  XVI  West Bay  2.004

# %%
df.dropna(inplace=True)
df.drop(['Phy'], axis=1, inplace=True)

plt.figure(figsize=(15,15))
sns.pairplot(df[['Chl_a','NO2','NO3','NH4','PO4','Bay']], 
             height=1.6, hue="Bay", markers=['X','o','D','^'],
             plot_kws={"s": 50,'alpha': 0.6}) 
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
X, y = df.iloc[:,1:5].to_numpy(), df['Chl_a'].to_numpy()

# Perform Standard Scaling then PCA on predictors, X

pca = make_pipeline(StandardScaler(), PCA())
X_pca = pca.fit(X).transform(X)
var = pca[1].explained_variance_ratio_
print("Explained variance ratio:    %s" % str(var))
print("Cumulative percent variance: %s" % str(np.cumsum(var)*100))

# Plot the first 2 principal components
pca_df = pd.DataFrame(data=np.c_[X_pca, df["Bay"]],
                      columns=['1st PC','2nd PC','3rd PC','4th PC','Bay'])
print(pca_df.head())
sns.jointplot(data=pca_df, x="1st PC", y="2nd PC", hue="Bay", s=50)
for txt, i in zip(df['Site'], range(len(X_pca))):
    plt.annotate(txt, (X_pca[i,0], X_pca[i,1]))
plt.show()
corr_matrix = df[['Chl_a','NO2','NO3','NH4','PO4']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='Blues')
plt.title('Correlation Matrix')
plt.show()
# Out:
# Explained variance ratio:    [0.66299171 0.19398164 0.11577687 0.02724979]
# Cumulative percent variance: [ 66.29917075  85.69733458  97.27502114 100.        ]
#       1st PC    2nd PC   3rd PC     4th PC       Bay
# 0   0.129604 -0.709483  1.24923  -0.424575  West Bay
# 1   0.129604 -0.709483  1.24923  -0.424575  West Bay
# 2   0.129604 -0.709483  1.24923  -0.424575  West Bay
# 3  0.0398513 -0.346665  1.12411 -0.0814897  West Bay
# 4  0.0398513 -0.346665  1.12411 -0.0814897  West Bay

# %% [markdown]
# The correlation matrix show that there is little correlation for dimensionality reduction to be effective. The 95% variance is explained by 3 predictors.

# %% [markdown]
# ## Train-test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42, stratify=df['Site'])
y_train, y_test = y_train.reshape(-1,1), y_test.reshape(-1,1)
scaler_X, scaler_y = StandardScaler(), StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
y_train_scaled = scaler_y.fit_transform(y_train)
X_test_scaled = scaler_X.transform(X_test)
y_test_scaled = scaler_y.transform(y_test)

# %% [markdown]
# ## Baseline Linear Regression on 4 Predictors

# %%
lin_mdl = LinearRegression().fit(X_train_scaled, y_train_scaled)
print(f"R2 on Train Set: {lin_mdl.score(X_train_scaled,y_train_scaled)}")
print(f"R2 on Test Set: {lin_mdl.score(X_test_scaled,y_test_scaled)}")
print("Coefficients: \n", lin_mdl.intercept_, lin_mdl.coef_)
print("Coefficient for:  NO_2, NO_3, NH_4, PO_4")

y_train_pred = scaler_y.inverse_transform(lin_mdl.predict(X_train_scaled))
y_test_pred = scaler_y.inverse_transform(lin_mdl.predict(X_test_scaled))

plt.subplots(ncols=2, figsize=(10, 4))
plt.subplot(121)
plt.scatter(y_train, y_train_pred, color='b')
plt.plot([3, 11],[3, 11],'k')
plt.xlabel('Actual Chl_a')
plt.ylabel('Predicted Chl_a')
plt.title('Training Data')
plt.grid()
plt.subplot(122)
plt.scatter(y_test, y_test_pred, color='b')
plt.plot([3, 11],[3, 11],'k')
plt.xlabel('Actual Chl_a')
plt.ylabel('Predicted Chl_a')
plt.title('Test Data')
plt.grid()
plt.show()
# Out:
# R2 on Train Set: 0.4537909157124268
# R2 on Test Set: 0.28757577902328124
# Coefficients:
#  [-2.43300555e-15] [[-0.08106809 -0.61488113 -0.26227254  0.92924602]]
# Coefficient for:  NO_2, NO_3, NH_4, PO_4

# %% [markdown]
# Baseline linear regression model shows poor predictive performance on Chl-a. Linear coefficients show the order of feature importance.

# %% [markdown]
# ## Prediction of Chl-a using Optuna: Model Selection and Tuning

# %%
def create_model(trial, model_type):
    #model_type = trial.suggest_categorical('model_type', ['KRR', 'kNN', 'SVR', 'MLP', 'RF', 'GBR', 'GPR'])
    
    if model_type == 'KRR':
        alpha = trial.suggest_float('KRR_alpha',0.01, 100, log=True)
        kernel = trial.suggest_categorical('KRR_kernel',
                                           ['rbf', 'polynomial', 'cosine', 'laplacian', 'sigmoid'])
        model = KernelRidge(alpha=alpha, kernel=kernel)
        
    if model_type == 'kNN':
        wts = trial.suggest_categorical('kNN_weights', ['uniform', 'distance'])
        n_neigh = trial.suggest_int('kNN_n_neighbors',1,20)
        model = KNeighborsRegressor(weights=wts,n_neighbors=n_neigh)
    
    if model_type == 'SVR':
        kernel = trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid'])
        C = trial.suggest_float('SVR-C', 0.1, 100, log=True)
        gamma = trial.suggest_float('SVR-gamma', 0.1, 100, log=True)
        epsi = trial.suggest_float('SVR-epsilon', 0.1, 100, log=True)
        degree = trial.suggest_int('SVR-degree', 1, 3, step=1)
        model = SVR(kernel=kernel, C=C, epsilon=epsi, gamma=gamma, degree=degree)
    
    if model_type == 'MLP':
        params = {
                    'learning_rate_init': trial.suggest_float('learning_rate_init ', 0.0001, 0.1, log=True),
                    'first_layer_neurons': trial.suggest_int('first_layer_neurons', 10, 100, step=1),
                    'second_layer_neurons': trial.suggest_int('second_layer_neurons', 10, 100, step=1),
                    'activation': trial.suggest_categorical('activation', ['identity', 'tanh', 'relu']),
                 }

        model = MLPRegressor(hidden_layer_sizes=(params['first_layer_neurons'], params['second_layer_neurons']),
                             learning_rate_init=params['learning_rate_init'],
                             activation=params['activation'],
                             random_state=1,
                             max_iter=100)
        
    if model_type == 'RF':
        n_estimators = trial.suggest_int('RF_n_estimators',10,200)
        crit = trial.suggest_categorical('RF_criterion', ['friedman_mse', 'squared_error', 'absolute_error'])
        model = RandomForestRegressor(n_estimators=n_estimators, criterion=crit, random_state=42)
        
    if model_type == 'GBR':
        n_estimators = trial.suggest_int('GBR_n_estimators',10,200)
        max_depth = trial.suggest_int('GBR_max_depth',1,50)
        model = GradientBoostingRegressor(n_estimators=n_estimators, max_depth=max_depth)
        
    if model_type == 'GPR':
        alpha = trial.suggest_float('GPR_alpha',0.01, 100, log=True)
        noise_level = trial.suggest_float('GPR_noise',0.01, 10, log=True)
        kernel_type = trial.suggest_categorical('GPR_kernel', ['rbf','matern','dot'])
        if kernel_type == 'rbf':
            length_scale = trial.suggest_float('GPR_length_scale',0.01, 10, log=True)
            model = GaussianProcessRegressor(kernel=WhiteKernel(noise_level) + RBF(length_scale=length_scale),
                                             alpha=alpha,
                                             normalize_y=False, 
                                             n_restarts_optimizer=10)
        if kernel_type == 'matern':
            length_scale = trial.suggest_float('GPR_length_scale',0.01, 10, log=True)
            nu = trial.suggest_float('GP_nu',0.5, 5, step=0.5)
            model = GaussianProcessRegressor(kernel=WhiteKernel(noise_level) + Matern(length_scale=length_scale,nu=nu),
                                             alpha=alpha,
                                             normalize_y=False, 
                                             n_restarts_optimizer=10)
        if kernel_type == 'dot':
            sigma = trial.suggest_float('GPR_dot_sigma', 0, 10)
            model = GaussianProcessRegressor(kernel=WhiteKernel(noise_level) + DotProduct(sigma_0=sigma),
                                             alpha=alpha,
                                             normalize_y=False, 
                                             n_restarts_optimizer=10)

    if trial.should_prune():
            raise optuna.TrialPruned()

    return model

def objective(trial, model_type):
    model = create_model(trial, model_type)
    scores = cross_val_score(model, 
                             X_train_scaled, 
                             y_train_scaled.ravel(), 
                             cv=5,
                             scoring='neg_mean_squared_error')
    return np.mean(scores)


sampler = TPESampler(seed=42)
best_mdls = []
studies = []
for model_type in ['KRR', 'kNN', 'SVR', 'MLP', 'RF', 'GBR', 'GPR']:
    study = optuna.create_study(direction='maximize', 
                                sampler=sampler)
    optuna_start = time()
    study.optimize(lambda trial: objective(trial, model_type), n_trials=150)
    studies.append(study)
    best_params = study.best_params
    print("\n\nBest parameters: ", best_params)
    total_time = time()-optuna_start
    print("Runtime: %.4f sec" % total_time)
    best_mdls.append(create_model(study.best_trial, model_type))
# Out:
# [I 2023-09-18 15:54:59,192] A new study created in memory with name: no-name-f48e8356-a89f-4074-8a0b-dbf6e13735a6
# [I 2023-09-18 15:54:59,294] Trial 0 finished with value: -0.35122720811758507 and parameters: {'KRR_alpha': 0.31489116479568624, 'KRR_kernel': 'rbf'}. Best is trial 0 with value: -0.35122720811758507.
# [I 2023-09-18 15:54:59,317] Trial 1 finished with value: -0.43846511179511954 and parameters: {'KRR_alpha': 0.017073967431528128, 'KRR_kernel': 'sigmoid'}. Best is trial 0 with value: -0.35122720811758507.
# [I 2023-09-18 15:54:59,330] Trial 2 finished with value: -1.2360531007497508 and parameters: {'KRR_alpha': 21.368329072358772, 'KRR_kernel': 'sigmoid'}. Best is trial 0 with value: -0.35122720811758507.
# [I 2023-09-18 15:54:59,335] Trial 3 finished with value: -0.37839436567708506 and parameters: {'KRR_alpha': 0.5342937261279778, 'KRR_kernel': 'polynomial'}. Best is trial 0 with value: -0.35122720811758507.
# [I 2023-09-18 15:54:59,349] Trial 4 finished with value: -0.39398719273850813 and parameters: {'KRR_alpha': 0.6672367170464207, 'KRR_kernel': 'rbf'}. Best is trial 0 with value: -0.35122720811758507.
# [I 2023-09-18 15:54:59,362] Trial 5 finished with value: -0.5563292620046487 and parameters: {'KRR_alpha': 2.69264691008618, 'KRR_kernel': 'laplacian'}. Best is trial 0 with value: -0.35122720811758507.
# [I 2023-09-18 15:54:59,369] Trial 6 finished with value: -0.3782637230746461 and parameters: {'KRR_alpha': 0.1653693718282443, 'KRR_kernel': 'polynomial'}. Best is trial 0 with value: -0.35122720811758507.
# [I 2023-09-18 15:54:59,380] Trial 7 finished with value: -0.26903337178307074 and parameters: {'KRR_alpha': 0.013726318898045875, 'KRR_kernel': 'rbf'}. Best is trial 7 with value: -0.26903337178307074.
# [I 2023-09-18 15:54:59,383] Trial 8 finished with value: -0.403735675873451 and parameters: {'KRR_alpha': 1.5375920235481764, 'KRR_kernel': 'polynomial'}. Best is trial 7 with value: -0.26903337178307074.
# [I 2023-09-18 15:54:59,398] Trial 9 finished with value: -0.5307633756222725 and parameters: {'KRR_alpha': 2.463768595899747, 'KRR_kernel': 'rbf'}. Best is trial 7 with value: -0.26903337178307074.
# [I 2023-09-18 15:54:59,414] Trial 10 finished with value: -0.7859802250251986 and parameters: {'KRR_alpha': 0.012079687909604592, 'KRR_kernel': 'cosine'}. Best is trial 7 with value: -0.26903337178307074.
# [I 2023-09-18 15:54:59,428] Trial 11 finished with value: -0.2947119888922953 and parameters: {'KRR_alpha': 0.06461911655408847, 'KRR_kernel': 'rbf'}. Best is trial 7 with value: -0.26903337178307074.
# [I 2023-09-18 15:54:59,437] Trial 12 finished with value: -0.28850369750731 and parameters: {'KRR_alpha': 0.051982451583531035, 'KRR_kernel': 'rbf'}. Best is trial 7 with value: -0.26903337178307074.
# [I 2023-09-18 15:54:59,451] Trial 13 finished with value: -0.2818035262367772 and parameters: {'KRR_alpha': 0.040183633913514864, 'KRR_kernel': 'rbf'}. Best is trial 7 with value: -0.26903337178307074.
# [I 2023-09-18 15:54:59,467] Trial 14 finished with value: -0.21355119513305967 and parameters: {'KRR_alpha': 0.012034419494522056, 'KRR_kernel': 'laplacian'}. Best is trial 14 with value: -0.21355119513305967.
# [I 2023-09-18 15:54:59,483] Trial 15 finished with value: -0.21410657813198447 and parameters: {'KRR_alpha': 0.0108450783268258, 'KRR_kernel': 'laplacian'}. Best is trial 14 with value: -0.21355119513305967.
# [I 2023-09-18 15:54:59,498] Trial 16 finished with value: -0.24187451440587773 and parameters: {'KRR_alpha': 0.1391288622990579, 'KRR_kernel': 'laplacian'}. Best is trial 14 with value: -0.21355119513305967.
# [I 2023-09-18 15:54:59,501] Trial 17 finished with value: -0.213715634336402 and parameters: {'KRR_alpha': 0.011662305849273118, 'KRR_kernel': 'laplacian'}. Best is trial 14 with value: -0.21355119513305967.
# [I 2023-09-18 15:54:59,518] Trial 18 finished with value: -0.2116157869672647 and parameters: {'KRR_alpha': 0.03014448423453645, 'KRR_kernel': 'laplacian'}. Best is trial 18 with value: -0.2116157869672647.
# [I 2023-09-18 15:54:59,533] Trial 19 finished with value: -0.2119427728554164 and parameters: {'KRR_alpha': 0.03312801220967041, 'KRR_kernel': 'laplacian'}. Best is trial 18 with value: -0.2116157869672647.
# [I 2023-09-18 15:54:59,548] Trial 20 finished with value: -0.7857568588126217 and parameters: {'KRR_alpha': 0.04412358679714859, 'KRR_kernel': 'cosine'}. Best is trial 18 with value: -0.2116157869672647.
# [I 2023-09-18 15:54:59,562] Trial 21 finished with value: -0.21211254406590205 and parameters: {'KRR_alpha': 0.034398893027484646, 'KRR_kernel': 'laplacian'}. Best is trial 18 with value: -0.2116157869672647.
# [I 2023-09-18 15:54:59,568] Trial 22 finished with value: -0.22857464831674937 and parameters: {'KRR_alpha': 0.0962075357027562, 'KRR_kernel': 'laplacian'}. Best is trial 18 with value: -0.2116157869672647.
# [I 2023-09-18 15:54:59,585] Trial 23 finished with value: -0.21194423510260368 and parameters: {'KRR_alpha': 0.03313953141975255, 'KRR_kernel': 'laplacian'}. Best is trial 18 with value: -0.2116157869672647.
# [I 2023-09-18 15:54:59,597] Trial 24 finished with value: -0.2113931855236079 and parameters: {'KRR_alpha': 0.02685754215348231, 'KRR_kernel': 'laplacian'}. Best is trial 24 with value: -0.2113931855236079.
# [I 2023-09-18 15:54:59,602] Trial 25 finished with value: -0.25736561182195483 and parameters: {'KRR_alpha': 0.19134775745525462, 'KRR_kernel': 'laplacian'}. Best is trial 24 with value: -0.2113931855236079.
# [I 2023-09-18 15:54:59,620] Trial 26 finished with value: -0.2253708546691271 and parameters: {'KRR_alpha': 0.08582084931032208, 'KRR_kernel': 'laplacian'}. Best is trial 24 with value: -0.2113931855236079.
# [I 2023-09-18 15:54:59,633] Trial 27 finished with value: -0.21150931073879203 and parameters: {'KRR_alpha': 0.020593506712726174, 'KRR_kernel': 'laplacian'}. Best is trial 24 with value: -0.2113931855236079.
# [I 2023-09-18 15:54:59,647] Trial 28 finished with value: -0.3982166630185243 and parameters: {'KRR_alpha': 0.021060859541976017, 'KRR_kernel': 'sigmoid'}. Best is trial 24 with value: -0.2113931855236079.
# [I 2023-09-18 15:54:59,653] Trial 29 finished with value: -0.7849405354240633 and parameters: {'KRR_alpha': 0.2966569294991545, 'KRR_kernel': 'cosine'}. Best is trial 24 with value: -0.2113931855236079.
# [I 2023-09-18 15:54:59,669] Trial 30 finished with value: -0.21144331750259027 and parameters: {'KRR_alpha': 0.021427452166064256, 'KRR_kernel': 'laplacian'}. Best is trial 24 with value: -0.2113931855236079.
# [I 2023-09-18 15:54:59,688] Trial 31 finished with value: -0.2116278893619909 and parameters: {'KRR_alpha': 0.01946978391659715, 'KRR_kernel': 'laplacian'}. Best is trial 24 with value: -0.2113931855236079.
# [I 2023-09-18 15:54:59,706] Trial 32 finished with value: -0.21134544357267648 and parameters: {'KRR_alpha': 0.025110810529491275, 'KRR_kernel': 'laplacian'}. Best is trial 32 with value: -0.21134544357267648.
# [I 2023-09-18 15:54:59,718] Trial 33 finished with value: -0.5893908134380264 and parameters: {'KRR_alpha': 0.07386599011417125, 'KRR_kernel': 'sigmoid'}. Best is trial 32 with value: -0.21134544357267648.
# [I 2023-09-18 15:54:59,733] Trial 34 finished with value: -0.2113776348441149 and parameters: {'KRR_alpha': 0.02646002629070298, 'KRR_kernel': 'laplacian'}. Best is trial 32 with value: -0.21134544357267648.
# [I 2023-09-18 15:54:59,750] Trial 35 finished with value: -0.21139678085382974 and parameters: {'KRR_alpha': 0.02221904960263714, 'KRR_kernel': 'laplacian'}. Best is trial 32 with value: -0.21134544357267648.
# [I 2023-09-18 15:54:59,763] Trial 36 finished with value: -0.42182787647589215 and parameters: {'KRR_alpha': 0.05694753021815778, 'KRR_kernel': 'polynomial'}. Best is trial 32 with value: -0.21134544357267648.
# [I 2023-09-18 15:54:59,778] Trial 37 finished with value: -0.8760815342402474 and parameters: {'KRR_alpha': 0.12073245822160457, 'KRR_kernel': 'sigmoid'}. Best is trial 32 with value: -0.21134544357267648.
# [I 2023-09-18 15:54:59,786] Trial 38 finished with value: -0.29246813183933446 and parameters: {'KRR_alpha': 0.3264338561478084, 'KRR_kernel': 'laplacian'}. Best is trial 32 with value: -0.21134544357267648.
# [I 2023-09-18 15:54:59,804] Trial 39 finished with value: -0.21134199002857348 and parameters: {'KRR_alpha': 0.02457638410094328, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,816] Trial 40 finished with value: -0.4083962584727727 and parameters: {'KRR_alpha': 0.07163168130315276, 'KRR_kernel': 'polynomial'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,833] Trial 41 finished with value: -0.211369756684763 and parameters: {'KRR_alpha': 0.022864838030407935, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,847] Trial 42 finished with value: -0.2144118373746018 and parameters: {'KRR_alpha': 0.010262567638120548, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,863] Trial 43 finished with value: -0.21206569640244294 and parameters: {'KRR_alpha': 0.016797322087323117, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,880] Trial 44 finished with value: -0.21610839803095053 and parameters: {'KRR_alpha': 0.0536235168443069, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,895] Trial 45 finished with value: -0.7858930705767898 and parameters: {'KRR_alpha': 0.024047345888891934, 'KRR_kernel': 'cosine'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,900] Trial 46 finished with value: -0.21367636065521825 and parameters: {'KRR_alpha': 0.04322287616046617, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,924] Trial 47 finished with value: -0.212234630275772 and parameters: {'KRR_alpha': 0.01604242230089068, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,941] Trial 48 finished with value: -0.47365765153005085 and parameters: {'KRR_alpha': 0.028585423423537076, 'KRR_kernel': 'polynomial'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,953] Trial 49 finished with value: -0.3089148073251997 and parameters: {'KRR_alpha': 0.10222949712382053, 'KRR_kernel': 'rbf'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,969] Trial 50 finished with value: -0.21242199222359837 and parameters: {'KRR_alpha': 0.015302797663854712, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,982] Trial 51 finished with value: -0.21138765806430687 and parameters: {'KRR_alpha': 0.02672382085513733, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:54:59,995] Trial 52 finished with value: -0.21403762436928236 and parameters: {'KRR_alpha': 0.04491748888190037, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,008] Trial 53 finished with value: -0.21171819339607598 and parameters: {'KRR_alpha': 0.031190594897652656, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,018] Trial 54 finished with value: -0.21246885930567005 and parameters: {'KRR_alpha': 0.015130666522170516, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,036] Trial 55 finished with value: -0.22148289029010235 and parameters: {'KRR_alpha': 0.07292294208795892, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,048] Trial 56 finished with value: -0.34858383236677176 and parameters: {'KRR_alpha': 0.05521487834562396, 'KRR_kernel': 'sigmoid'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,064] Trial 57 finished with value: -0.21170481758131698 and parameters: {'KRR_alpha': 0.031061593548644673, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,082] Trial 58 finished with value: -0.7859821712809001 and parameters: {'KRR_alpha': 0.011819371523204284, 'KRR_kernel': 'cosine'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,099] Trial 59 finished with value: -0.2724927506804139 and parameters: {'KRR_alpha': 0.025349556579032446, 'KRR_kernel': 'rbf'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,116] Trial 60 finished with value: -0.2127288641738181 and parameters: {'KRR_alpha': 0.038296821492096074, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,129] Trial 61 finished with value: -0.21135172356163562 and parameters: {'KRR_alpha': 0.023526446698042432, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,135] Trial 62 finished with value: -0.21235691228518777 and parameters: {'KRR_alpha': 0.015549846952361545, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,153] Trial 63 finished with value: -0.2145938398668754 and parameters: {'KRR_alpha': 0.047398191467384596, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,168] Trial 64 finished with value: -0.2113714549960552 and parameters: {'KRR_alpha': 0.026279385528261836, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,184] Trial 65 finished with value: -0.21324081109246756 and parameters: {'KRR_alpha': 0.01279241141762889, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,201] Trial 66 finished with value: -0.21265428494954636 and parameters: {'KRR_alpha': 0.037865778210179314, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,216] Trial 67 finished with value: -0.21175621390529448 and parameters: {'KRR_alpha': 0.018524376467958303, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,229] Trial 68 finished with value: -0.21134350472950647 and parameters: {'KRR_alpha': 0.024114815537019645, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,244] Trial 69 finished with value: -0.42110141672814577 and parameters: {'KRR_alpha': 0.05760802976633773, 'KRR_kernel': 'polynomial'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,249] Trial 70 finished with value: -0.2142804710549499 and parameters: {'KRR_alpha': 0.010507886091337218, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,266] Trial 71 finished with value: -0.2113582440914147 and parameters: {'KRR_alpha': 0.025817778479841205, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,282] Trial 72 finished with value: -0.21241158451986544 and parameters: {'KRR_alpha': 0.036396521995842965, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,284] Trial 73 finished with value: -0.2115090315895468 and parameters: {'KRR_alpha': 0.020596608667320195, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,302] Trial 74 finished with value: -0.21271946728112004 and parameters: {'KRR_alpha': 0.01428036123733689, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,318] Trial 75 finished with value: -0.2113599088230918 and parameters: {'KRR_alpha': 0.023182510157393844, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,333] Trial 76 finished with value: -2.383885174873349 and parameters: {'KRR_alpha': 0.018596015158687286, 'KRR_kernel': 'sigmoid'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,346] Trial 77 finished with value: -0.7854746561981203 and parameters: {'KRR_alpha': 0.09305320927490794, 'KRR_kernel': 'cosine'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,349] Trial 78 finished with value: -0.272890902198434 and parameters: {'KRR_alpha': 0.010243833677883512, 'KRR_kernel': 'rbf'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,374] Trial 79 finished with value: -0.21138877188309957 and parameters: {'KRR_alpha': 0.022388290213352136, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,381] Trial 80 finished with value: -0.2133438622754888 and parameters: {'KRR_alpha': 0.04158794832532008, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,400] Trial 81 finished with value: -0.21210949334613716 and parameters: {'KRR_alpha': 0.03437710303174934, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,416] Trial 82 finished with value: -0.21135267458171988 and parameters: {'KRR_alpha': 0.025567913629712388, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,431] Trial 83 finished with value: -0.2113627112865503 and parameters: {'KRR_alpha': 0.025989172028022763, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,432] Trial 84 finished with value: -0.21954993957213914 and parameters: {'KRR_alpha': 0.06627576951207315, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,458] Trial 85 finished with value: -0.21299534058689865 and parameters: {'KRR_alpha': 0.013453835315217023, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,466] Trial 86 finished with value: -0.2117992131704768 and parameters: {'KRR_alpha': 0.018246604758817692, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,483] Trial 87 finished with value: -0.21135536042227265 and parameters: {'KRR_alpha': 0.023360290171348, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,499] Trial 88 finished with value: -0.21527781323897094 and parameters: {'KRR_alpha': 0.0502880741083673, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,514] Trial 89 finished with value: -0.46930647888697646 and parameters: {'KRR_alpha': 0.030097752153421854, 'KRR_kernel': 'polynomial'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,516] Trial 90 finished with value: -0.21194204884121004 and parameters: {'KRR_alpha': 0.017421120600612496, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,533] Trial 91 finished with value: -0.2113503705598372 and parameters: {'KRR_alpha': 0.023596265425637596, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,549] Trial 92 finished with value: -0.21134221208548812 and parameters: {'KRR_alpha': 0.024674808524883494, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,566] Trial 93 finished with value: -0.21304145827331294 and parameters: {'KRR_alpha': 0.013324778328067723, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,579] Trial 94 finished with value: -0.21194936675866444 and parameters: {'KRR_alpha': 0.03317986806464752, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,587] Trial 95 finished with value: -0.2114175247359404 and parameters: {'KRR_alpha': 0.02183395300745377, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,600] Trial 96 finished with value: -0.21324909146266413 and parameters: {'KRR_alpha': 0.04110605979746995, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,615] Trial 97 finished with value: -0.5012491808742396 and parameters: {'KRR_alpha': 0.017565598976853135, 'KRR_kernel': 'sigmoid'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,635] Trial 98 finished with value: -0.7858692024435927 and parameters: {'KRR_alpha': 0.027437065403515946, 'KRR_kernel': 'cosine'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,650] Trial 99 finished with value: -0.21473239309567482 and parameters: {'KRR_alpha': 0.047996283181763084, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,667] Trial 100 finished with value: -0.21866066644548637 and parameters: {'KRR_alpha': 0.06313195265472032, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,682] Trial 101 finished with value: -0.2113420291144014 and parameters: {'KRR_alpha': 0.024601728541541162, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,697] Trial 102 finished with value: -0.21136950854586725 and parameters: {'KRR_alpha': 0.022872043728467906, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,714] Trial 103 finished with value: -0.21173271613323053 and parameters: {'KRR_alpha': 0.03132847368223434, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,728] Trial 104 finished with value: -0.21251049012893092 and parameters: {'KRR_alpha': 0.014981545913594185, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,741] Trial 105 finished with value: -0.2699151402352415 and parameters: {'KRR_alpha': 0.02060296749830275, 'KRR_kernel': 'rbf'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,755] Trial 106 finished with value: -0.2126254154745338 and parameters: {'KRR_alpha': 0.03769656541662988, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,771] Trial 107 finished with value: -0.2133931976105409 and parameters: {'KRR_alpha': 0.012410455751814457, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,787] Trial 108 finished with value: -0.21134199472226028 and parameters: {'KRR_alpha': 0.024441247347437543, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,801] Trial 109 finished with value: -0.21162944806428627 and parameters: {'KRR_alpha': 0.03029277866582938, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,815] Trial 110 finished with value: -0.21227058000763172 and parameters: {'KRR_alpha': 0.015893454500226226, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,828] Trial 111 finished with value: -0.21134429167161137 and parameters: {'KRR_alpha': 0.02500141051383787, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,841] Trial 112 finished with value: -0.21136380501392188 and parameters: {'KRR_alpha': 0.026028332711116178, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,853] Trial 113 finished with value: -0.21172406408548966 and parameters: {'KRR_alpha': 0.018743231041306287, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,870] Trial 114 finished with value: -0.21338001807163104 and parameters: {'KRR_alpha': 0.04176979358992359, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,885] Trial 115 finished with value: -0.45597887553743616 and parameters: {'KRR_alpha': 0.03542046392334712, 'KRR_kernel': 'polynomial'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,899] Trial 116 finished with value: -0.2235611869026939 and parameters: {'KRR_alpha': 0.07987430114855636, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,913] Trial 117 finished with value: -0.21465615518782225 and parameters: {'KRR_alpha': 0.04766806555846645, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,915] Trial 118 finished with value: -0.21134462173587804 and parameters: {'KRR_alpha': 0.025035047699309, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,932] Trial 119 finished with value: -0.21727396350105868 and parameters: {'KRR_alpha': 0.0580757557835721, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,947] Trial 120 finished with value: -0.6306557260746193 and parameters: {'KRR_alpha': 0.012582388080215556, 'KRR_kernel': 'sigmoid'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,966] Trial 121 finished with value: -0.21134252484200547 and parameters: {'KRR_alpha': 0.02475341019588107, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,981] Trial 122 finished with value: -0.21151316318424826 and parameters: {'KRR_alpha': 0.020550986087957666, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,994] Trial 123 finished with value: -0.211611642551776 and parameters: {'KRR_alpha': 0.030098863129761552, 'KRR_kernel': 'laplacian'}. Best is trial 39 with value: -0.21134199002857348.
# [I 2023-09-18 15:55:00,998] Trial 124 finished with value: -0.21134198202629814 and parameters: {'KRR_alpha': 0.024451252684332455, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,016] Trial 125 finished with value: -0.21172703614608088 and parameters: {'KRR_alpha': 0.018722561607134754, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,038] Trial 126 finished with value: -0.7858166983701459 and parameters: {'KRR_alpha': 0.035078815664363286, 'KRR_kernel': 'cosine'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,049] Trial 127 finished with value: -0.21249483566520383 and parameters: {'KRR_alpha': 0.015037216260440528, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,065] Trial 128 finished with value: -0.27205186770036255 and parameters: {'KRR_alpha': 0.02460938474537697, 'KRR_kernel': 'rbf'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,082] Trial 129 finished with value: -0.21417097977155192 and parameters: {'KRR_alpha': 0.010718470794714505, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,096] Trial 130 finished with value: -0.21148639739383204 and parameters: {'KRR_alpha': 0.028528680474358685, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,099] Trial 131 finished with value: -0.21136932358351013 and parameters: {'KRR_alpha': 0.02287743685618556, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,117] Trial 132 finished with value: -0.2120179282884045 and parameters: {'KRR_alpha': 0.01703004481613482, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,134] Trial 133 finished with value: -0.2129425344491073 and parameters: {'KRR_alpha': 0.039488471771040465, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,154] Trial 134 finished with value: -0.21141228372678014 and parameters: {'KRR_alpha': 0.021925296995557265, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,167] Trial 135 finished with value: -0.2114132705632184 and parameters: {'KRR_alpha': 0.02729388566052116, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,181] Trial 136 finished with value: -0.21195478415429156 and parameters: {'KRR_alpha': 0.033222301525738476, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,186] Trial 137 finished with value: -0.21294332282394005 and parameters: {'KRR_alpha': 0.013602309923916754, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,214] Trial 138 finished with value: -0.21467092352927725 and parameters: {'KRR_alpha': 0.04773181151636385, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,228] Trial 139 finished with value: -0.21151530350722555 and parameters: {'KRR_alpha': 0.020527590841558058, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,235] Trial 140 finished with value: -0.5204639351623014 and parameters: {'KRR_alpha': 0.016847908817296284, 'KRR_kernel': 'polynomial'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,249] Trial 141 finished with value: -0.2113423203251148 and parameters: {'KRR_alpha': 0.02470560044695511, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,266] Trial 142 finished with value: -0.21134408954285427 and parameters: {'KRR_alpha': 0.02404682464770393, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,281] Trial 143 finished with value: -0.21149931466815114 and parameters: {'KRR_alpha': 0.02871334606336867, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,287] Trial 144 finished with value: -0.21270485368008812 and parameters: {'KRR_alpha': 0.0381589778452891, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,302] Trial 145 finished with value: -0.2113423233495728 and parameters: {'KRR_alpha': 0.02470639178641879, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,317] Trial 146 finished with value: -0.21160857986608547 and parameters: {'KRR_alpha': 0.01963186740204651, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,333] Trial 147 finished with value: -0.4139800644407413 and parameters: {'KRR_alpha': 1.0667461660387743, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,346] Trial 148 finished with value: -0.211780209465071 and parameters: {'KRR_alpha': 0.031764953555188394, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,361] Trial 149 finished with value: -0.21227484358001206 and parameters: {'KRR_alpha': 0.015876026957212304, 'KRR_kernel': 'laplacian'}. Best is trial 124 with value: -0.21134198202629814.
# [I 2023-09-18 15:55:01,362] A new study created in memory with name: no-name-a9b23a99-f1c4-41cb-996f-a6e16fd2f2b2
# [I 2023-09-18 15:55:01,414] Trial 0 finished with value: -0.8735556302690559 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 17}. Best is trial 0 with value: -0.8735556302690559.
# [I 2023-09-18 15:55:01,421] Trial 1 finished with value: -0.7307119795675334 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 11}. Best is trial 1 with value: -0.7307119795675334.
# [I 2023-09-18 15:55:01,429] Trial 2 finished with value: -0.26100783898697494 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 2}. Best is trial 2 with value: -0.26100783898697494.
# [I 2023-09-18 15:55:01,431] Trial 3 finished with value: -0.345998109097268 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 4}. Best is trial 2 with value: -0.26100783898697494.
# [I 2023-09-18 15:55:01,431] Trial 4 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,448] Trial 5 finished with value: -0.26100783898697494 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 2}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,457] Trial 6 finished with value: -0.880757447435454 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 18}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,465] Trial 7 finished with value: -0.3032712379785226 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 2}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,467] Trial 8 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,481] Trial 9 finished with value: -0.2546878004520403 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 10}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,488] Trial 10 finished with value: -0.25360024711946166 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 12}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,500] Trial 11 finished with value: -0.2477582796837098 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 14}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,515] Trial 12 finished with value: -0.251686533453614 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 20}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,523] Trial 13 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,534] Trial 14 finished with value: -0.2463313976010062 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 9}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,549] Trial 15 finished with value: -0.24290441764058412 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 7}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,562] Trial 16 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 4 with value: -0.24165258805251408.
# Best parameters:  {'KRR_alpha': 0.024451252684332455, 'KRR_kernel': 'laplacian'}
# Runtime: 2.1666 sec
# [I 2023-09-18 15:55:01,575] Trial 17 finished with value: -0.2535706501175062 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 13}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,583] Trial 18 finished with value: -0.24237523187548865 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 17}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,597] Trial 19 finished with value: -0.24290441764058412 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 7}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,598] Trial 20 finished with value: -0.251686533453614 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 20}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,615] Trial 21 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 4 with value: -0.24165258805251408.
# [I 2023-09-18 15:55:01,632] Trial 22 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,644] Trial 23 finished with value: -0.24454722217889713 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 18}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,651] Trial 24 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,665] Trial 25 finished with value: -0.24237523187548865 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 17}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,680] Trial 26 finished with value: -0.2535706501175062 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 13}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,682] Trial 27 finished with value: -0.8923384506223184 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 19}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,699] Trial 28 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,717] Trial 29 finished with value: -0.8735556302690559 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 17}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,728] Trial 30 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,734] Trial 31 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,748] Trial 32 finished with value: -0.25360024711946166 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 12}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,765] Trial 33 finished with value: -0.24454722217889713 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 18}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,777] Trial 34 finished with value: -0.8012610445817859 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 13}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,782] Trial 35 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,798] Trial 36 finished with value: -0.24901878063848662 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 19}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,814] Trial 37 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,827] Trial 38 finished with value: -0.8277767872470637 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 14}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,837] Trial 39 finished with value: -0.25180553736482614 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 11}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,849] Trial 40 finished with value: -0.8923384506223184 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 19}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,865] Trial 41 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,877] Trial 42 finished with value: -0.2477582796837098 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 14}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,882] Trial 43 finished with value: -0.24237523187548865 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 17}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,899] Trial 44 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,915] Trial 45 finished with value: -0.24454722217889713 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 18}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,927] Trial 46 finished with value: -0.2477582796837098 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 14}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,934] Trial 47 finished with value: -0.25360024711946166 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 12}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,949] Trial 48 finished with value: -0.2463313976010062 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 9}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,965] Trial 49 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,977] Trial 50 finished with value: -0.24786929236508567 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 5}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,981] Trial 51 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:01,998] Trial 52 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,014] Trial 53 finished with value: -0.24237523187548865 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 17}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,028] Trial 54 finished with value: -0.24454722217889713 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 18}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,041] Trial 55 finished with value: -0.2477582796837098 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 14}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,055] Trial 56 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,069] Trial 57 finished with value: -0.2535706501175062 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 13}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,081] Trial 58 finished with value: -0.251686533453614 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 20}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,096] Trial 59 finished with value: -0.8503550581920118 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,103] Trial 60 finished with value: -0.24901878063848662 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 19}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,115] Trial 61 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,133] Trial 62 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,148] Trial 63 finished with value: -0.24237523187548865 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 17}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,165] Trial 64 finished with value: -0.24237523187548865 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 17}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,182] Trial 65 finished with value: -0.24454722217889713 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 18}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,198] Trial 66 finished with value: -0.2477582796837098 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 14}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,211] Trial 67 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,217] Trial 68 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,231] Trial 69 finished with value: -0.8377135702112698 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 15}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,249] Trial 70 finished with value: -0.346670638457847 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 1}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,265] Trial 71 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,278] Trial 72 finished with value: -0.24237523187548865 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 17}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,284] Trial 73 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,299] Trial 74 finished with value: -0.2535706501175062 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 13}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,315] Trial 75 finished with value: -0.24237523187548865 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 17}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,331] Trial 76 finished with value: -0.24454722217889713 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 18}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,344] Trial 77 finished with value: -0.2477582796837098 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 14}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,351] Trial 78 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,365] Trial 79 finished with value: -0.8923384506223184 and parameters: {'kNN_weights': 'uniform', 'kNN_n_neighbors': 19}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,384] Trial 80 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,402] Trial 81 finished with value: -0.23900262754269921 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 16}. Best is trial 22 with value: -0.23900262754269921.
# [I 2023-09-18 15:55:02,415] Trial 82 finished with value: -0.24165258805251408 and parameters: {'kNN_weights': 'distance', 'kNN_n_neighbors': 15}. Best is trial 22 with value: -0.23900262754269921.
# ...
# [I 2023-09-18 15:59:56,243] Trial 97 finished with value: -0.2371730268478248 and parameters: {'GPR_alpha': 0.06166922735301195, 'GPR_noise': 0.22860526662409025, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.16817299459737786, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 15:59:57,141] Trial 98 finished with value: -0.656228657992777 and parameters: {'GPR_alpha': 0.058081155476377336, 'GPR_noise': 0.2987156060231382, 'GPR_kernel': 'dot', 'GPR_dot_sigma': 0.08868417891339853}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 15:59:57,842] Trial 99 finished with value: -0.23982047913490145 and parameters: {'GPR_alpha': 0.1101961435008022, 'GPR_noise': 0.24259501883742815, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.17594648544679717, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 15:59:59,723] Trial 100 finished with value: -0.24472597114899033 and parameters: {'GPR_alpha': 0.07166655607956993, 'GPR_noise': 0.18009016119331456, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.18048601939569056, 'GP_nu': 1.0}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:00,363] Trial 101 finished with value: -0.23711208552597424 and parameters: {'GPR_alpha': 0.05662027580016337, 'GPR_noise': 0.20579710546719038, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.11080179341230906, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:02,034] Trial 102 finished with value: -0.258685045101937 and parameters: {'GPR_alpha': 0.08978246196672508, 'GPR_noise': 0.1373949649824154, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.11457790942392934, 'GP_nu': 4.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:02,866] Trial 103 finished with value: -0.24127464682165084 and parameters: {'GPR_alpha': 0.14039286272489981, 'GPR_noise': 0.22390204182817958, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.21757556328103902, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:03,478] Trial 104 finished with value: -0.23715093182437408 and parameters: {'GPR_alpha': 0.06034329889755568, 'GPR_noise': 0.2723151192767201, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.11004285341174452, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:04,064] Trial 105 finished with value: -0.23716701119526032 and parameters: {'GPR_alpha': 0.06133317544316856, 'GPR_noise': 0.3784114243819279, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.07472159969972714, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:04,711] Trial 106 finished with value: -0.23720734751701805 and parameters: {'GPR_alpha': 0.06334960945374928, 'GPR_noise': 0.3894402199025674, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.07245141119047087, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:06,268] Trial 107 finished with value: -0.24370715558388087 and parameters: {'GPR_alpha': 0.10130194821667177, 'GPR_noise': 0.2706133535410132, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.13705417265686817, 'GP_nu': 1.0}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:06,850] Trial 108 finished with value: -0.23717426228442534 and parameters: {'GPR_alpha': 0.06173613882724891, 'GPR_noise': 0.36520489418414065, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.10047091052447818, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:07,256] Trial 109 finished with value: -0.3058112541158053 and parameters: {'GPR_alpha': 0.07908415269561558, 'GPR_noise': 0.3954161366353453, 'GPR_kernel': 'rbf', 'GPR_length_scale': 0.10161836928728113}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:08,884] Trial 110 finished with value: -0.24511808542182711 and parameters: {'GPR_alpha': 0.06347203015164186, 'GPR_noise': 0.32893401696818975, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.12624776459442666, 'GP_nu': 1.0}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:09,525] Trial 111 finished with value: -0.2371494572498088 and parameters: {'GPR_alpha': 0.060243887125889406, 'GPR_noise': 0.49844891738039837, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.07825210554581111, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:10,031] Trial 112 finished with value: -0.2380490831528018 and parameters: {'GPR_alpha': 0.08244603854577322, 'GPR_noise': 0.5217381623484363, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.07759324196794684, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:10,848] Trial 113 finished with value: -0.23715481049781933 and parameters: {'GPR_alpha': 0.060596509180588495, 'GPR_noise': 0.2632589323020736, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.1088065915333548, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:11,768] Trial 114 finished with value: -0.23850778495701067 and parameters: {'GPR_alpha': 0.03015475073829653, 'GPR_noise': 0.27051389269868586, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.07902455487998687, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:13,324] Trial 115 finished with value: -0.2435324475425845 and parameters: {'GPR_alpha': 0.13271702713951192, 'GPR_noise': 0.2414433700804427, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.0662488599445591, 'GP_nu': 1.0}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:13,863] Trial 116 finished with value: -0.2418722034927129 and parameters: {'GPR_alpha': 0.15974750112015998, 'GPR_noise': 0.4811985994728825, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.09684942598722346, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:14,489] Trial 117 finished with value: -0.25226433186903596 and parameters: {'GPR_alpha': 0.10852637684396271, 'GPR_noise': 0.2953313269829698, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.110427394690306, 'GP_nu': 2.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:15,359] Trial 118 finished with value: -0.23762163967119684 and parameters: {'GPR_alpha': 0.04347911311019157, 'GPR_noise': 0.2111058195690246, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.12705826759504132, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:16,177] Trial 119 finished with value: -0.6562286538794153 and parameters: {'GPR_alpha': 0.07511158638509594, 'GPR_noise': 0.1775637561181763, 'GPR_kernel': 'dot', 'GPR_dot_sigma': 4.032676175237363}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:16,863] Trial 120 finished with value: -0.23712536299124237 and parameters: {'GPR_alpha': 0.05829455315252472, 'GPR_noise': 0.2622161739674294, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.07996213575592888, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:17,476] Trial 121 finished with value: -0.23713549741673573 and parameters: {'GPR_alpha': 0.05920905286031933, 'GPR_noise': 0.26770290789267925, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.0832216640457832, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:18,144] Trial 122 finished with value: -0.23897548447689934 and parameters: {'GPR_alpha': 0.09666934359187633, 'GPR_noise': 0.3442416269788814, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.08172018633552638, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:18,976] Trial 123 finished with value: -0.23773879843269477 and parameters: {'GPR_alpha': 0.04159199705636924, 'GPR_noise': 0.27791159048280634, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.06523946714951687, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:19,888] Trial 124 finished with value: -0.23860925650264891 and parameters: {'GPR_alpha': 0.029047193912693496, 'GPR_noise': 0.4557187477715714, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.09047737737486092, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:21,765] Trial 125 finished with value: -0.24468844966522701 and parameters: {'GPR_alpha': 0.07249938239514833, 'GPR_noise': 0.2523220819680671, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.07582053404339582, 'GP_nu': 1.0}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:22,355] Trial 126 finished with value: -0.23710647289518652 and parameters: {'GPR_alpha': 0.055318708355156114, 'GPR_noise': 0.34221521242240116, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.10608609129211875, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:23,187] Trial 127 finished with value: -0.23766391113434376 and parameters: {'GPR_alpha': 0.04275615709875295, 'GPR_noise': 0.3220215031824514, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.14320941347687932, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:25,123] Trial 128 finished with value: -0.24555219345154464 and parameters: {'GPR_alpha': 0.05521193092110366, 'GPR_noise': 0.12224218223631832, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.10254793085320615, 'GP_nu': 1.0}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:25,669] Trial 129 finished with value: -0.26783232272148855 and parameters: {'GPR_alpha': 0.08665884683642558, 'GPR_noise': 0.2027434467373281, 'GPR_kernel': 'rbf', 'GPR_length_scale': 0.12102998808609437}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:26,570] Trial 130 finished with value: -0.23853448699647556 and parameters: {'GPR_alpha': 0.02986303636486422, 'GPR_noise': 0.17576622640503084, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.06198771872176041, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:27,264] Trial 131 finished with value: -0.23712096231605395 and parameters: {'GPR_alpha': 0.057825858108922185, 'GPR_noise': 0.43467036384078994, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.10322465862799425, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:28,150] Trial 132 finished with value: -0.23783013904697065 and parameters: {'GPR_alpha': 0.040181863473364575, 'GPR_noise': 0.5241979319492005, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.0938184983091361, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:28,909] Trial 133 finished with value: -0.240557806819034 and parameters: {'GPR_alpha': 0.12393913564673122, 'GPR_noise': 0.6148729775047921, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.11354404811851596, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:29,574] Trial 134 finished with value: -0.23710722555230035 and parameters: {'GPR_alpha': 0.052693531340187734, 'GPR_noise': 0.2550032177457246, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.14654463881028754, 'GP_nu': 0.5}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:31,678] Trial 135 finished with value: -0.24598257839743445 and parameters: {'GPR_alpha': 0.045571846460045716, 'GPR_noise': 0.276972961757179, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.08718761583286753, 'GP_nu': 1.0}. Best is trial 91 with value: -0.23710531372746738.
# [I 2023-09-18 16:00:32,577] Trial 136 finished with value: -0.2371052282088791 and parameters: {'GPR_alpha': 0.054720298236561875, 'GPR_noise': 0.2361102206495183, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.10446793379408148, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:33,305] Trial 137 finished with value: -0.23784353610935266 and parameters: {'GPR_alpha': 0.07895629584124261, 'GPR_noise': 0.22915168921056348, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.1508237049512941, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:33,915] Trial 138 finished with value: -0.23710797169483633 and parameters: {'GPR_alpha': 0.05248354125069933, 'GPR_noise': 0.3451150042386359, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.12569439071135086, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:34,611] Trial 139 finished with value: -0.2371093599020769 and parameters: {'GPR_alpha': 0.05215312541012045, 'GPR_noise': 0.34980874594029443, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.1961785126986769, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:35,421] Trial 140 finished with value: -0.23833106756143754 and parameters: {'GPR_alpha': 0.03263107707450525, 'GPR_noise': 0.34128437934378936, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.21295356755249206, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:36,140] Trial 141 finished with value: -0.23710867765455243 and parameters: {'GPR_alpha': 0.052306503027906924, 'GPR_noise': 0.4280827459265462, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.09814281031248193, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:37,014] Trial 142 finished with value: -0.23762442213164542 and parameters: {'GPR_alpha': 0.0434119039447823, 'GPR_noise': 0.43335382707856507, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.12333677211382923, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:37,575] Trial 143 finished with value: -0.23716957248289566 and parameters: {'GPR_alpha': 0.050388474802251663, 'GPR_noise': 0.4095997534583609, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.1544641769245953, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:38,527] Trial 144 finished with value: -0.2386112588431891 and parameters: {'GPR_alpha': 0.026460258056288995, 'GPR_noise': 0.19852231887249022, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.12964918728218072, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:41,085] Trial 145 finished with value: -0.24629057049229947 and parameters: {'GPR_alpha': 0.0381260252140856, 'GPR_noise': 0.1663454365278377, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.09624945706081561, 'GP_nu': 1.0}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:41,779] Trial 146 finished with value: -0.23914675137753633 and parameters: {'GPR_alpha': 0.09929154262509969, 'GPR_noise': 0.3511087904597835, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.18587390827460584, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:42,462] Trial 147 finished with value: -0.23711431264582417 and parameters: {'GPR_alpha': 0.05125823936419573, 'GPR_noise': 0.14273665775770392, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.14475785937000846, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:43,467] Trial 148 finished with value: -0.6562286501227698 and parameters: {'GPR_alpha': 0.07493420046661033, 'GPR_noise': 0.12849596847969616, 'GPR_kernel': 'dot', 'GPR_dot_sigma': 2.1898739295437277}. Best is trial 136 with value: -0.2371052282088791.
# [I 2023-09-18 16:00:44,347] Trial 149 finished with value: -0.23840671920670023 and parameters: {'GPR_alpha': 0.0315147684383917, 'GPR_noise': 0.14167250899128656, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.14179750130673835, 'GP_nu': 0.5}. Best is trial 136 with value: -0.2371052282088791.
# Best parameters:  {'GPR_alpha': 0.054720298236561875, 'GPR_noise': 0.2361102206495183, 'GPR_kernel': 'matern', 'GPR_length_scale': 0.10446793379408148, 'GP_nu': 0.5}
# Runtime: 175.8781 sec

# %%
def compute_mse(X, y):
    scores_mse = cross_val_score(best_model, 
                                 X, y.ravel(), 
                                 cv=5, 
                                 scoring='neg_mean_squared_error')
    return -np.mean(scores_mse)

def compute_r2(X, y):
    scores_r2 = cross_val_score(best_model, 
                                X, y.ravel(), 
                                cv=5, 
                                scoring='r2')
    return np.mean(scores_r2)

mdl_names = ['KRR', 'kNN', 'SVR', 'MLP', 'RF', 'GBR', 'GPR'] 
ctr = 0
plt.figure(figsize=(10,5))
for best_model in best_mdls:
    best_model.fit(X_train_scaled, y_train_scaled)
    
    print(f"{mdl_names[ctr]}")
    print("  Best cross-validation score (R2) : %.5f" % compute_r2(X_train_scaled,y_train_scaled))
    print("  Best cross-validation score (MSE): %.5f" % compute_mse(X_train_scaled,y_train_scaled))
    y_train_pred = best_model.predict(X_train_scaled)
    R2_train = r2_score(y_train_scaled,y_train_pred)
    print("  Performance on train data (R2) :  %.5f" % R2_train)
    mse_train = mean_squared_error(y_train_scaled,y_train_pred)
    print("  Performance on train data (MSE):  %.5f" % mse_train)
    y_test_pred = best_model.predict(X_test_scaled)
    R2_test = r2_score(y_test_scaled,y_test_pred)
    print("  Performance on test data (R2)  :  %.5f" % R2_test)
    mse_test = mean_squared_error(y_test_scaled,y_test_pred)
    print("  Performance on test data (MSE) :  %.5f" % mse_test)
    
    X_scaled = np.vstack((X_train_scaled, X_test_scaled))
    y_scaled = np.vstack((y_train_scaled, y_test_scaled))
    y_pred = best_model.predict(X_scaled)
    R2_all = r2_score(y_scaled, y_pred)
    print("  Performance on all data (R2)   :  %.5f" % R2_all)
    mse_all = mean_squared_error(y_scaled, y_pred)
    print("  Performance on all data (MSE)  :  %.5f" % mse_all)
    
    info_list = _get_optimization_history_info_list(studies[ctr], 
                                                    target=None,
                                                    target_name="Objective Value", 
                                                    error_bar=False)
    plt.plot(info_list[0].trial_numbers,
             info_list[0].best_values_info.values, 'o-')
    ctr+=1

plt.ylabel('5-fold cross-validation score (Negative MSE)')
plt.xlabel('BayesOpt Trial Number')
plt.title('Hyper-parameter Search Progress for all Models')
plt.legend(mdl_names)
plt.ylim((-0.4,-0.1))
plt.grid()
plt.show()
# Out:
# KRR
#   Best cross-validation score (R2) : 0.73503
#   Best cross-validation score (MSE): 0.21134
#   Performance on train data (R2) :  0.96615
#   Performance on train data (MSE):  0.03385
#   Performance on test data (R2)  :  0.92503
#   Performance on test data (MSE) :  0.07544
#   Performance on all data (R2)   :  0.94968
#   Performance on all data (MSE)  :  0.05064
# kNN
#   Best cross-validation score (R2) : 0.75378
#   Best cross-validation score (MSE): 0.23900
#   Performance on train data (R2) :  0.97667
#   Performance on train data (MSE):  0.02333
#   Performance on test data (R2)  :  0.92307
#   Performance on test data (MSE) :  0.07742
#   Performance on all data (R2)   :  0.95512
#   Performance on all data (MSE)  :  0.04516
# SVR
#   Best cross-validation score (R2) : 0.77682
#   Best cross-validation score (MSE): 0.19276
#   Performance on train data (R2) :  0.89090
#   Performance on train data (MSE):  0.10910
#   Performance on test data (R2)  :  0.91740
#   Performance on test data (MSE) :  0.08312
#   Performance on all data (R2)   :  0.90201
#   Performance on all data (MSE)  :  0.09861
# MLP
#   Best cross-validation score (R2) : 0.78958
#   Best cross-validation score (MSE): 0.16620
#   Performance on train data (R2) :  0.93111
#   Performance on train data (MSE):  0.06889
#   Performance on test data (R2)  :  0.91240
#   Performance on test data (MSE) :  0.08816
#   Performance on all data (R2)   :  0.92381
#   Performance on all data (MSE)  :  0.07667
# RF
#   Best cross-validation score (R2) : 0.69177
#   Best cross-validation score (MSE): 0.22632
#   Performance on train data (R2) :  0.95029
#   Performance on train data (MSE):  0.04971
#   Performance on test data (R2)  :  0.91350
#   Performance on test data (MSE) :  0.08706
#   Performance on all data (R2)   :  0.93562
#   Performance on all data (MSE)  :  0.06479
# GBR
#   Best cross-validation score (R2) : 0.67258
#   Best cross-validation score (MSE): 0.23174
#   Performance on train data (R2) :  0.94532
#   Performance on train data (MSE):  0.05468
#   Performance on test data (R2)  :  0.91036
#   Performance on test data (MSE) :  0.09022
#   Performance on all data (R2)   :  0.93141
#   Performance on all data (MSE)  :  0.06902
# GPR
#   Best cross-validation score (R2) : 0.74762
#   Best cross-validation score (MSE): 0.23711
#   Performance on train data (R2) :  0.97499
#   Performance on train data (MSE):  0.02501
#   Performance on test data (R2)  :  0.90525
#   Performance on test data (MSE) :  0.09536
#   Performance on all data (R2)   :  0.94693
#   Performance on all data (MSE)  :  0.05340

# %% [markdown]
# ## Shapley Explanation on All Optuna Models

# %%
import shap
for best_model in best_mdls:
    print(best_model)
    shap_values = shap.KernelExplainer(best_model.predict,X_test_scaled)
    background = shap.maskers.Independent(X_test_scaled, max_samples=1000)
    explainer = shap.Explainer(best_model.predict, background)
    shap_values = explainer(X_test_scaled)

    # Plot the feature importance using SHAP
    shap.summary_plot(shap_values, X_test_scaled, feature_names=['NO2','NO3','NH4','PO4'])
# Out:
# KernelRidge(alpha=0.024451252684332455, kernel='laplacian')
# KNeighborsRegressor(n_neighbors=16, weights='distance')
# SVR(C=18.706661783641433, epsilon=0.16688034091906265, gamma=0.4990318697594256)
# MLPRegressor(hidden_layer_sizes=(69, 79),
#              learning_rate_init=0.015333338068444533, max_iter=100,
#              random_state=1)
# RandomForestRegressor(criterion='absolute_error', n_estimators=111,
#                       random_state=42)
# GradientBoostingRegressor(max_depth=2, n_estimators=61)
# GaussianProcessRegressor(alpha=0.054720298236561875,
#                          kernel=WhiteKernel(noise_level=0.236) + Matern(length_scale=0.104, nu=0.5),
#                          n_restarts_optimizer=10)

# %% [markdown]
# ## Relating Total-N/Total-P ratio to Chl-a

# %%
X2 = np.sum(X[:,:2],axis=1)/X[:,-1]
X2 = X2.reshape(-1,1)

plt.subplots(ncols=2, figsize=(12, 4))
plt.subplot(121)
plt.scatter(X2,y)
plt.ylabel('Chl-a')
plt.xlabel('N/P ratio (without NH4)')
plt.yscale('log')
plt.xscale('log')
plt.grid()
plt.subplot(122)
X3 = np.sum(X[:,:3],axis=1)/X[:,-1]
plt.scatter(X3,y)
plt.ylabel('Chl-a')
plt.xlabel('N/P ratio (with NH4)')
plt.yscale('log')
plt.xscale('log')
plt.grid()
plt.show()

# %% [markdown]
# ## Robustness Analysis due to Imperfect Measurements (using Monte Carlo)

# %%
N = 50
ctr = 0
R2_train_all = np.zeros((N+1,7))
R2_test_all = np.zeros((N+1,7))

for best_model in best_mdls:
    
    print(best_model)
    mdl = best_model.fit(X_train_scaled, y_train_scaled)
    y_train = mdl.predict(X_train_scaled)
    y_test = mdl.predict(X_test_scaled)
    R2_train = r2_score(y_train_scaled,y_train)
    R2_test = r2_score(y_test_scaled,y_test)
    print("Original:")
    print("  Performance on train data (R2): %.5f" % R2_train)
    print("  Performance on test data (R2): %.5f" % R2_test)
    y_train_ = scaler_y.inverse_transform(y_train.reshape(-1,1))
    y_test_ = scaler_y.inverse_transform(y_test.reshape(-1,1))

    y_train_collect = y_train_
    y_test_collect = y_test_
    R2_train_collect = R2_train
    R2_test_collect = R2_test
    y_train_, y_test_ = y_train_.ravel(), y_test_.ravel()

    for i in range(N):
        np.random.RandomState(0)
        noise_train = np.random.normal(0,0.1,X_train_scaled.shape)
        noise_test = np.random.normal(0,0.1,X_test_scaled.shape)
        mdl_noise = best_model.fit(X_train_scaled + noise_train, y_train_scaled)
        y_train2 = mdl_noise.predict(X_train_scaled + noise_train)
        y_test2 = mdl_noise.predict(X_test_scaled + noise_test)
        R2_train2 = r2_score(y_train_scaled,y_train2)
        R2_test2 = r2_score(y_test_scaled,y_test2)
        R2_train_collect = np.hstack((R2_train_collect,R2_train2))
        R2_test_collect = np.hstack((R2_test_collect,R2_test2))
        y_train2_ = scaler_y.inverse_transform(y_train2.reshape(-1,1))
        y_test2_ = scaler_y.inverse_transform(y_test2.reshape(-1,1))
        y_train_collect = np.hstack((y_train_collect,y_train2_))
        y_test_collect = np.hstack((y_test_collect,y_test2_))

    y_train_true = scaler_y.inverse_transform(y_train_scaled.reshape(-1,1)).ravel()
    y_test_true = scaler_y.inverse_transform(y_test_scaled.reshape(-1,1)).ravel()
    R2_train_all[:,ctr] = R2_train_collect
    R2_test_all[:,ctr] = R2_test_collect
    ctr += 1

    # Sort all y according to true values
    train_id = np.argsort(y_train_true)
    test_id = np.argsort(y_test_true)
    y_train_true = y_train_true[train_id]
    y_test_true = y_test_true[test_id]
    y_train_ = y_train_[train_id]
    y_test_ = y_test_[test_id]
    y_train_collect = y_train_collect[train_id,:]
    y_test_collect = y_test_collect[test_id,:]

    plt.subplots(ncols=2, figsize=(10, 4))
    plt.subplot(121)
    for i in range(N):
        plt.scatter(y_train_true, y_train_collect[:,i], color='c', alpha=0.1)
    plt.scatter(y_train_true, y_train_, color='b')
    plt.plot([2, 11],[2, 11],'k')
    plt.xlabel('Actual Chl_a')
    plt.ylabel('Predicted Chl_a')
    plt.title("Training Data")
    plt.grid()
    plt.subplot(122)
    for i in range(N):
        plt.scatter(y_test_true, y_test_collect[:,i], color='c', alpha=0.1)
    plt.scatter(y_test_true, y_test_, color='b')
    plt.plot([2, 11],[2, 11],'k')
    plt.xlabel('Actual Chl_a')
    plt.ylabel('Predicted Chl_a')
    plt.title(f"Test Data")
    plt.grid()
    plt.savefig(f"fig_mdl{ctr}.png",dpi=900)
    plt.show()
# Out:
# KernelRidge(alpha=0.024451252684332455, kernel='laplacian')
# Original:
#   Performance on train data (R2): 0.96615
#   Performance on test data (R2): 0.92503
# KNeighborsRegressor(n_neighbors=16, weights='distance')
# Original:
#   Performance on train data (R2): 0.97667
#   Performance on test data (R2): 0.92307
# SVR(C=18.706661783641433, epsilon=0.16688034091906265, gamma=0.4990318697594256)
# Original:
#   Performance on train data (R2): 0.89090
#   Performance on test data (R2): 0.91740
# MLPRegressor(hidden_layer_sizes=(69, 79),
#              learning_rate_init=0.015333338068444533, max_iter=100,
#              random_state=1)
# Original:
#   Performance on train data (R2): 0.93111
#   Performance on test data (R2): 0.91240
# RandomForestRegressor(criterion='absolute_error', n_estimators=111,
#                       random_state=42)
# Original:
#   Performance on train data (R2): 0.95029
#   Performance on test data (R2): 0.91350
# GradientBoostingRegressor(max_depth=2, n_estimators=61)
# Original:
#   Performance on train data (R2): 0.94532
#   Performance on test data (R2): 0.91036
# GaussianProcessRegressor(alpha=0.054720298236561875,
#                          kernel=WhiteKernel(noise_level=0.236) + Matern(length_scale=0.104, nu=0.5),
#                          n_restarts_optimizer=10)
# Original:
#   Performance on train data (R2): 0.97499
#   Performance on test data (R2): 0.90525

# %%
plt.subplots(ncols=2, figsize=(12, 4))
plt.subplot(121)
boxprops = dict(linewidth=2, color='b')
plt.boxplot(R2_train_all, boxprops=boxprops)
plt.title('Training $R^2$ Variation')
plt.xticks(np.arange(7)+1,["KRR","kNN","SVR","MLP","RF","GBR","GPR"])
plt.ylim(0.4, 1.00)
plt.ylabel('Accuracy ($R^2$)')
plt.grid()
plt.subplot(122)
plt.boxplot(R2_test_all, boxprops=boxprops)
plt.title('Testing $R^2$ Variation')
plt.xticks(np.arange(7)+1,["KRR","kNN","SVR","MLP","RF","GBR","GPR"])
plt.ylim(0.4, 1.00)
plt.ylabel('Accuracy ($R^2$)')
plt.grid()
plt.savefig('fig_robust.png',dpi=900)
plt.show()

total_time = time()-start
print("Total Runtime: %.4f sec" % total_time)
# Out:
# Total Runtime: 473.0226 sec

# %%
print(np.median(R2_train_all,axis=0))
print(np.median(R2_test_all,axis=0))
# Out:
# [0.98576581 1.         0.87515021 0.94279235 0.93615931 0.90665027
#  0.97885016]
# [0.79639434 0.66432157 0.83760259 0.80022969 0.76166128 0.64251814
#  0.82153309]
